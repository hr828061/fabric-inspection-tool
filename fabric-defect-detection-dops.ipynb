# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.3/896.3 kB 14.3 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
torch.cuda.empty_cache()

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 83.3MB/s]

# %%
data = '/kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/data.yaml'

# %%
results = model.train(data=data,epochs=50,imgsz=640,pretrained=False)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.train(data=data,epochs=250,imgsz=640,pretrained=False)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/valid/labels... 31 images, 0 backgrounds, 0 corrupt: 100%|██████████| 31/31 [00:00<00:00, 537.19it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/valid is not writeable, cache not saved.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.43it/s]
#                    all         31         41      0.637      0.609       0.61      0.307
# ...

# %%
# Run inference
results = model.predict('/kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/test/images/DSC03123_JPG.rf.3f07734016a78c67337b0fedc1f3e70e.jpg',save=True,conf=0.5)
# Out:
# image 1/1 /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/test/images/DSC03123_JPG.rf.3f07734016a78c67337b0fedc1f3e70e.jpg: 640x640 1 Knot, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train23

# %%
import cv2

# %%
from IPython.display import Image, display
display(Image(filename="/kaggle/working/runs/detect/train23/DSC03123_JPG.rf.3f07734016a78c67337b0fedc1f3e70e.jpg", width=1000))

# %%
# Run inference
results = model.predict('/kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/test/images/a00003_jpg.rf.41811eb9fdc1b70c2bd6881e46306b53.jpg',save=True,conf=0.5)
# Out:
# image 1/1 /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/test/images/a00003_jpg.rf.41811eb9fdc1b70c2bd6881e46306b53.jpg: 640x640 (no detections), 8.3ms
# Speed: 3.4ms preprocess, 8.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train24

# %%
from IPython.display import Image, display
display(Image(filename="/kaggle/working/runs/detect/train24/a00003_jpg.rf.41811eb9fdc1b70c2bd6881e46306b53.jpg", width=1000))

# %%
display(Image(filename="/kaggle/working/runs/detect/train2/confusion_matrix_normalized.png", width=1000))

# %%
display(Image(filename="/kaggle/working/runs/detect/train2/results.png", width=1000))

# %%
display(Image(filename="/kaggle/working/runs/detect/train2/PR_curve.png", width=1000))

# %%
display(Image(filename="/kaggle/working/runs/detect/train2/F1_curve.png", width=1000))

# %%
display(Image(filename="/kaggle/working/runs/detect/train2/val_batch0_pred.jpg", width=1000))

# %%
#Validation
display(Image(filename="/kaggle/working/runs/detect/train22/val_batch1_pred.jpg", width=1000))

# %%
model.eval()
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
#FineTuning
model = YOLO('yolov8s.pt')
results = model.train(data='/kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/data.yaml', epochs=80, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#FineTuning
model = YOLO('yolov8s.pt')
results = model.train(data='/kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/data.yaml', epochs=280, imgsz=640, batch=16)
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrices = model.val()
# Out:
# Ultralytics 8.3.38 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/valid/labels... 31 images, 0 backgrounds, 0 corrupt: 100%|██████████| 31/31 [00:00<00:00, 599.65it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/valid is not writeable, cache not saved.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.60it/s]
#                    all         31         41      0.662      0.552      0.571      0.252
# ...

# %%
model.predict('/kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/test/images/a00001_jpg.rf.13a28619cc3f10490c8d86d7fefa382d.jpg',save=True,conf=0.5)
# Out:
# image 1/1 /kaggle/input/fabric-3/Fabric Defect Detection.v5-v1.yolov8/test/images/a00001_jpg.rf.13a28619cc3f10490c8d86d7fefa382d.jpg: 640x640 1 Hole, 16.2ms
# Speed: 4.5ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train43
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hole', 1: 'Knot', 2: 'Stain'}
#  obb: None
#  orig_img: array([[[148, 175, 165],
#          [155, 182, 172],
#          [159, 186, 176],
#          ...,
#          [155, 181, 168],
#          [154, 180, 167],
#          [153, 179, 166]],
#
#         [[151, 178, 168],
#          [154, 181, 171],
#          [156, 183, 173],
#          ...,
#          [156, 182, 169],
#          [154, 180, 167],
#          [153, 179, 166]],
#
#         [[153, 180, 170],
#          [153, 180, 170],
#          [152, 179, 169],
#          ...,
# ...

# %%
import shutil
folder_path = '/kaggle/working/runs/detect/train43'
shutil.make_archive('Testing1', 'zip', folder_path)
# Out:
# '/kaggle/working/Testing1.zip'

# %%
model.save('/kaggle/working/yolov8n_model.pt')
